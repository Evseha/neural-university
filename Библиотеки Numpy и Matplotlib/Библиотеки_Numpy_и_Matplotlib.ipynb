# %%
# Импорт необходимых библиотек
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Создайдим двумерный массив размерностью **3** на **4**, состоящий из случайных целых чисел от **15** до **37**.
#
# Требуется создать новый массив той же размерности (3,4), значения которого будут зависеть от значений исходного массива и могут принимать одно из трех возможных значений:
#
# * **"small"**, для значений исходного массива меньше **20**;
# * **"medium"**, для значений исходного массива в промежутке **[20, 30]**;
# * **"large"**, для значений исходного массива  больше **30**.
#
# Пример:
#
# *Исходный массив*:
#
#         [[18 34 27 36]
#          [16 25 24 29]
#          [16 18 36 16]]
#
# Реузльтирующий массив должен выглядеть следующим образом:
#
#         [['small' 'large' 'medium' 'large']
#          ['small' 'medium' 'medium' 'medium']
#          ['small' 'small' 'large' 'small']]

# %% [markdown]
# При решении задания нам может пригодиться метод numpy.full()
#
# ---
# Дополнительная информация ([База знаний УИИ - «**Метод numpy.full()**»](https://colab.research.google.com/drive/1oa4X8o27GkeurzSFVO9x0SoIp_gt6hFd?usp=sharing))
#
# ---

# %%
my_array = np.random.randint(15, 38, size=(3,4))
print(my_array)
# Out:
# [[20 36 19 22]
#  [15 37 32 20]
#  [23 26 24 24]]

# %%
new_array = np.full((3,4), 'medium', dtype='<U8')
new_array[my_array < 20] = 'small'
new_array[my_array > 30] = 'large'
print(new_array)
# Out:
# [['medium' 'large' 'small' 'medium']
#  ['small' 'large' 'large' 'medium']
#  ['medium' 'medium' 'medium' 'medium']]

# %% [markdown]
# ### Задача 2

# %% [markdown]
# С помощью встроенных методов библиотеки `numpy` найдем дату первого понедельника в 2015 году.
#
# ---
#
# Наш результат может выглядеть так:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# При решении задания нам может пригодиться метод `np.busday_offset()`
#
# ---
# Дополнительная информация ([База знаний УИИ - «**Функции DateTime в Numpy**»](https://colab.research.google.com/drive/1gSg4eZkpGwP0Zs5VGhl8uMhoo2Gmsil6?usp=sharing))
#
# ---

# %%
jan_1_2015 = np.datetime64('2015-01-01')
print('начальная дата', jan_1_2015)

print('Первый понедельник в 2015 году', np.busday_offset(jan_1_2015, 0, roll='forward', weekmask='Mon'))
# Out:
# начальная дата 2015-01-01
# Первый понедельник в 2015 году 2015-01-05

# %% [markdown]
# ### Задача 3

# %% [markdown]
# Реализуем алгоритм сортировки массива пузырьком.
#
# **Сортировка пузырьком** - это метод сортировки массивов и списков путем последовательного сравнения и обмена соседних элементов, если предшествующий оказывается больше последующего. В процессе выполнения данного алгоритма элементы с большими значениями оказываются в конце списка, а элементы с меньшими значениями постепенно перемещаются по направлению к началу списка. Образно говоря, тяжелые элементы падают на дно, а легкие медленно всплывают подобно пузырькам воздуха.
#
# ---
# Наш результат может выглядеть так:
#
# ![image.png](data:image/png;base64,...)

# %%
# Ваше решение
def bubble_sort(list1):
    for i in range(0, len(list1)-1):
      for j in range(len(list1)-1):
        if(list1[j]>list1[j+1]):
          temp = list1[j]
          list1[j] = list1[j+1]
          list1[j+1] = temp
    return list1

list1 = np.random.randint(1, 100, 10)

print('Сгенерированный массив:\n', list1)
print()
print('Отсортированный массив:\n' , bubble_sort(list1))
# Out:
# Сгенерированный массив:
#  [99 86 11 38 94 99 60 14 50 31]
#
# Отсортированный массив:
#  [11 14 31 38 50 60 86 94 99 99]

# %% [markdown]
# ### Задача 4

# %% [markdown]
# Нарисуем график рассеяния со случайным распределением по осям X и Y.
#
# ---
#
# Наш результат может выглядеть так:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# При решении задания нам может пригодиться метод `plt.scatter()`
#
# ---
# Дополнительная информация ([База знаний УИИ - «**Scatter - график разброса**»](https://colab.research.google.com/drive/1DvReBj0GxdwVaQ72WUleiIwQGer1-vfn?usp=sharing))
#
# ---

# %%
''' случайные координаты точек '''
x = np.random.randint(0, 1000, 200)    #  x - координаты
y = np.random.randint(0, 1000, 200)    #  y - координаты

''' область и подобласть рисования '''
figure, axes = plt.subplots()

''' цвета точек '''
axes.scatter(x, y, c = 'red')

''' заголовок для Axes '''
axes.set_title('График рассеяния')
axes.set_ylabel('Y')
axes.set_xlabel('X')

''' ширина и высота "Figure" '''
figure.set_figwidth(5)
figure.set_figheight(4)

plt.show()

# %% [markdown]
# ### Задача 5

# %% [markdown]
# Даны два списка `x` и `y`
#
#         x = [-7, -5, 7, 9, 10, 10, 9, -7, 0, 5, 7, 4, 0, 6, 8, 4, 0]
#         y = [0, 2, 2, 5, 5, 1, 0, 0, 2, 6, 6, 2, 1, -3, -3, 1, 1]
#
# Построим два графика: `plot(x,y)` и `scatter(x,y)` на разных координатных плоскостях.
#
# Построим еще один график `plot(x,y)` размером **(6, 3)** со следущими элементами:
# - линиями сетки;
# - подписями осей х и y;
# - названием графика "Самолет".

# %%
x = [-7, -5, 7, 9, 10, 10, 9, -7, 0, 5, 7, 4, 0, 6, 8, 4, 0]
y = [0, 2, 2, 5, 5, 1, 0, 0, 2, 6, 6, 2, 1, -3, -3, 1, 1]

# %%
plt.plot(x, y)
plt.show()

# %%
figure, axes = plt.subplots()
axes.scatter(x, y, c = 'red')
figure.set_figwidth(5)
figure.set_figheight(4)
plt.show()

# %%
plt.figure(figsize=(6, 3))
plt.plot(x, y)
plt.grid()
plt.title('Самолет')
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')
